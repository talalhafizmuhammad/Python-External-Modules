# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
array = np.array([2, 3, 4, 5, 7, 9, 12, 13, 16, 17, 18, 21, 21, 23, 24, 28, 201])
array
# Out:
# array([  2,   3,   4,   5,   7,   9,  12,  13,  16,  17,  18,  21,  21,
#         23,  24,  28, 201])

# %%
Q1 = np.percentile(array, 25)
Q1
# Out:
# 7.0

# %%
Q3 = np.percentile(array, 75)
Q3
# Out:
# 21.0

# %%
IQR = Q3 - Q1
IQR
# Out:
# 14.0

# %%
Lower = Q1 - 1.5*IQR
Lower
# Out:
# -14.0

# %%
Upper = Q3 + 1.5*IQR
Upper
# Out:
# 42.0

# %%
mask = (array > Lower) & (array < Upper)   
mask = array[mask]
mask
# Out:
# array([ 2,  3,  4,  5,  7,  9, 12, 13, 16, 17, 18, 21, 21, 23, 24, 28])

# %%
plt.boxplot(array)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1a4aae02e40>,
#   <matplotlib.lines.Line2D at 0x1a4aae03110>],
#  'caps': [<matplotlib.lines.Line2D at 0x1a4aae03410>,
#   <matplotlib.lines.Line2D at 0x1a4aae036e0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1a4aae02b70>],
#  'medians': [<matplotlib.lines.Line2D at 0x1a4aae03980>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1a4aae03c20>],
#  'means': []}

# %%
plt.boxplot(x = mask)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1a4ab7091c0>,
#   <matplotlib.lines.Line2D at 0x1a4ab7094c0>],
#  'caps': [<matplotlib.lines.Line2D at 0x1a4ab709790>,
#   <matplotlib.lines.Line2D at 0x1a4ab6d7c50>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1a4ab708ec0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1a4ab709b80>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1a4ab709e80>],
#  'means': []}

# %%
sns.boxplot(x = array)
# Out:
# <Axes: >

# %%
sns.boxplot(x = mask)
# Out:
# <Axes: >

# %% [markdown]
# ## **Created By:** *Hafiz Muhammad Talal*
