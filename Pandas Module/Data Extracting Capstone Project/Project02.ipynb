# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Complete Data Capstone Project

# %%
df = pd.read_csv('Countries.csv')

# %%
df
# Out:
#                 country                             country_long  \
# 0           Afghanistan             Islamic State of Afghanistan
# 1               Albania                      Republic of Albania
# 2               Algeria  People's Democratic Republic of Algeria
# 3               Andorra                  Principality of Andorra
# 4                Angola              People's Republic of Angola
# ..                  ...                                      ...
# 189             Vietnam            Socialist Republic of Vietnam
# 190  West Bank and Gaza                       West Bank and Gaza
# 191               Yemen                        Republic of Yemen
# 192              Zambia                       Republic of Zambia
# 193            Zimbabwe                     Republic of Zimbabwe
#
#                currency      capital_city              region continent  \
# 0        Afghan afghani             Kabul       Southern Asia      Asia
# ...

# %%
df.shape
# Out:
# (194, 64)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 194 entries, 0 to 193
# Data columns (total 64 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   country                                  194 non-null    object
#  1   country_long                             194 non-null    object
#  2   currency                                 194 non-null    object
#  3   capital_city                             194 non-null    object
#  4   region                                   194 non-null    object
#  5   continent                                194 non-null    object
#  6   demonym                                  194 non-null    object
#  7   latitude                                 194 non-null    float64
#  8   longitude                                194 non-null    float64
#  9   agricultural_land                        193 non-null    float64
# ...

# %%
h = df['population'].max()
df[df['population'] == h] # Highest population country info
# Out:
#    country       country_long      currency capital_city         region  \
# 75   India  Republic of India  Indian rupee    New Delhi  Southern Asia
#
#    continent demonym  latitude  longitude  agricultural_land  ...  population  \
# 75      Asia  Indian      20.0       77.0          1790450.0  ...  1417173173
#
#     women_parliament_seats_pct  rural_population  urban_population  press  \
# 75                     14.9446         908804812         508368361   1.71
#
#     democracy_score    democracy_type  median_age  political_leader  \
# 75             7.23  Flawed democracy        23.9     Narendra Modi
#
#              title
# 75  Prime Minister
#
# [1 rows x 64 columns]

# %%
df.columns
# Out:
# Index(['country', 'country_long', 'currency', 'capital_city', 'region',
#        'continent', 'demonym', 'latitude', 'longitude', 'agricultural_land',
#        'forest_area', 'land_area', 'rural_land', 'urban_land',
#        'central_government_debt_pct_gdp', 'expense_pct_gdp', 'gdp',
#        'inflation', 'self_employed_pct', 'tax_revenue_pct_gdp',
#        'unemployment_pct', 'vulnerable_employment_pct',
#        'electricity_access_pct', 'alternative_nuclear_energy_pct',
#        'electricty_production_coal_pct',
#        'electricty_production_hydroelectric_pct',
#        'electricty_production_gas_pct', 'electricty_production_nuclear_pct',
#        'electricty_production_oil_pct', 'electricty_production_renewable_pct',
#        'energy_imports_pct', 'fossil_energy_consumption_pct',
#        'renewable_energy_consumption_pct', 'co2_emissions',
#        'methane_emissions', 'nitrous_oxide_emissions',
#        'greenhouse_other_emissions', 'urban_population_under_5m',
# ...

# %%
df[df['population'] == h]['country'] # Highest population country name
# Out:
# 75    India
# Name: country, dtype: object

# %%
df[df['population'] == h]['capital_city'] # Highest population country capital
# Out:
# 75    New Delhi
# Name: capital_city, dtype: object

# %%
df[df['population'] == h]['political_leader'] # Highest population country political leader
# Out:
# 75    Narendra Modi
# Name: political_leader, dtype: object

# %%
# Least populated country
l = df['population'].min()
df[df['population'] == l]
# Out:
#     country country_long           currency capital_city     region continent  \
# 179  Tuvalu       Tuvalu  Australian dollar     Funafuti  Polynesia   Oceania
#
#       demonym  latitude  longitude  agricultural_land  ...  population  \
# 179  Tuvaluan      -8.0      178.0               18.0  ...       11312
#
#      women_parliament_seats_pct  rural_population  urban_population  press  \
# 179                        6.25              3900              7412    0.0
#
#      democracy_score  democracy_type  median_age  political_leader  \
# 179              0.0         Unknown        21.0     Kausea Natano
#
#               title
# 179  Prime Minister
#
# [1 rows x 64 columns]

# %%
df[df['population'] == l]['political_leader'] # Political leader
# Out:
# 179    Kausea Natano
# Name: political_leader, dtype: object

# %%
# Top 5 countries with highest democracy score
arr = df.nlargest(5, 'democracy_score')[['country', 'democracy_score']]
arr
# Out:
#          country  democracy_score
# 127       Norway             9.87
# 74       Iceland             9.58
# 164       Sweden             9.39
# 122  New Zealand             9.26
# 46       Denmark             9.22

# %%
df['region'].value_counts() # regions
# Out:
# region
# Western Asia                 17
# Eastern Africa               17
# Western Africa               16
# Southern Europe              15
# Caribbean                    13
# South America                12
# South-Eastern Asia           11
# Northern Europe              10
# Middle Africa                10
# Eastern Europe               10
# Southern Asia                 9
# Western Europe                9
# Central America               8
# Northern Africa               6
# Southern Africa               5
# Eastern Asia                  5
# Central Asia                  5
# Micronesia                    5
# Melanesia                     4
# Polynesia                     3
# Australia and New Zealand     2
# Northern America              2
# Name: count, dtype: int64

# %%
df['region'].value_counts().count() # total how many regions
# Out:
# 22

# %%
df['region'].value_counts()['Eastern Europe'] # how many countries have eastern europe regions
# Out:
# 10

# %%
# All countries in eastern europe region
df[df['region'] == 'Eastern Europe']['country']
# Out:
# 14             Belarus
# 24            Bulgaria
# 43      Czech Republic
# 73             Hungary
# 111            Moldova
# 136             Poland
# 139            Romania
# 140             Russia
# 151    Slovak Republic
# 181            Ukraine
# Name: country, dtype: object

# %%
# political leader of the country with 2nd largest population
df[df['population'] == df['population'].nlargest(2).iloc[1]][['country', 'population', 'political_leader']]
# Out:
#    country  population political_leader
# 34   China  1412175000       Xi Jinping

# %%
republic_countries = df[df['country_long'].str.contains('Republic')] # Which countries have republic in their name
republic_countries
republic_countries_sum = df['country_long'].str.contains('Republic').sum() #count of the countries with republic in their name
republic_countries_sum
# Out:
# 125

# %%
# Countries with unknown political leaders
df[df['political_leader'].isna()][['country', 'country_long', 'political_leader']]
# Out:
#                             country                        country_long  \
# 27                       Cabo Verde              Republic of Cabo Verde
# 151                 Slovak Republic                     Slovak Republic
# 159             St. Kitts and Nevis                 St. Kitts and Nevis
# 160                       St. Lucia                           St. Lucia
# 161  St. Vincent and the Grenadines      St. Vincent and the Grenadines
# 172                     Timor-Leste  Democratic Republic of Timor-Leste
# 190              West Bank and Gaza                  West Bank and Gaza
#
#     political_leader
# 27               NaN
# 151              NaN
# 159              NaN
# 160              NaN
# 161              NaN
# 172              NaN
# 190              NaN

# %%
# Which country in african region has highest population
df_african = df[df['continent'] == 'Africa']
df_african[df_african['population'] == df_african['population'].max()][['country', 'population', 'region']]
# Out:
#      country  population          region
# 125  Nigeria   218541212  Western Africa
